# %% [markdown]
# <a href="https://colab.research.google.com/github/Pornphankub/dataviz2025/blob/main/midterm2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ให้สืบหาฆาตรกร (10 คะแนน) และ ผู้บงการ (5 คะแนน) ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง Pandas City โดยเริ่มจากการตรวจสอบ ข้อมูลคดีในไฟล์ crime_scene_report.csv

# %%
import os

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_to_crime_scene_report = '/content/drive/MyDrive/Python&DataViz2025/Midterm/crime_scene_report.csv'

# %%
crimescenereport_df = pd.read_csv(path_to_crime_scene_report)
crimescenereport_df.head()
# Out:
#        date     type                                        description  \
# 0  20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1  20180115   murder                  Life? Dont talk to me about life.
# 2  20180115   murder  Mama, I killed a man, put a gun against his he...
# 3  20180215   murder                         REDACTED REDACTED REDACTED
# 4  20180215   murder  Someone killed the guard! He took an arrow to ...
#
#           city
# 0          NYC
# 1       Albany
# 2         Reno
# 3  Pandas City
# 4  Pandas City

# %% [markdown]
# # หาคดีฆาตกรรมในวันที่ 15 มกราคม 2018

# %%
crime_in_date = crimescenereport_df[crimescenereport_df['date'] == 20180115]
crime_in_date
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 5     20180115    theft                    Big Bully stole my lunch money!
# 6     20180115    fraud  Lorem ipsum dolor sit amet, consectetur adipis...
# 11    20180115  assault  Hamilton: Lee, do you yield? Burr: You shot hi...
# 12    20180115  assault                                   Report Not Found
# 972   20180115    arson  like a mouse, you know. But do cats eat bats, ...
# 973   20180115  bribery  Here the other guinea-pig cheered, and was sup...
# 974   20180115    fraud  The Dormouse slowly opened his eyes. ‘I wasn’t...
# 975   20180115    fraud  King put on his spectacles and looked anxiousl...
# ...

# %%
murder_in_date = crime_in_date[crime_in_date['type'].str.contains('murder')]
murder_in_date
# Out:
#           date    type                                        description  \
# 1     20180115  murder                  Life? Dont talk to me about life.
# 2     20180115  murder  Mama, I killed a man, put a gun against his he...
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#              city
# 1          Albany
# 2            Reno
# 1227  Pandas City

# %%
murder_in_pandas_city = murder_in_date[murder_in_date['city'] == 'Pandas City']
murder_in_pandas_city
# Out:
#           date    type                                        description  \
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#              city
# 1227  Pandas City

# %%
if not murder_in_pandas_city.empty:
    for index, row in murder_in_pandas_city.iterrows():
        print(f"--- รายละเอียดข้อมูล: {index} ---")
        for column, value in row.items():
            print(f"{column}: {value}")
else:
    print("DataFrame 'murder_in_pandas_city' is empty.")
# Out:
# --- รายละเอียดข้อมูล: 1227 ---
# date: 20180115
# type: murder
# description: Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
# city: Pandas City

# %% [markdown]
# สรุปข้อมูล
#
# --- รายละเอียดข้อมูล: 1227 ---
#
# date: 20180115
#
# type: murder
#
# description: ภาพจากกล้องวงจรปิดแสดงให้เห็นว่ามีพยาน 2 คน พยานคนแรกอาศัยอยู่ที่บ้านหลังสุดท้ายบนถนน "Northwestern Dr" พยานคนที่สองชื่อ Annabel อาศัยอยู่ที่ไหนสักแห่งบนถนน "Franklin Ave".
#
# city: Pandas City

# %% [markdown]
# ## หาข้อมูลพยานคนที่ 1

# %%
path_to_person = '/content/drive/MyDrive/Python&DataViz2025/Midterm/person.csv'

# %%
person_df = pd.read_csv(path_to_person)
person_df
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
person1_df = person_df[person_df['address_street_name'] == 'Northwestern Dr']
person1_df
# Out:
#          id                  name  license_id  address_number  \
# 2     10010             Muoi Cary      385336             741
# 282   12711        Norman Apolito      667757             599
# 499   14887        Morty Schapiro      118009            4919
# 528   15171          Weldon Penso      336999             311
# 811   17729        Lasonya Wildey      439686            3824
# 904   18376              Josh Shi      653712            1091
# 1021  19420           Cody Schiel      890431            3524
# 1338  22239         Dusty Sigafus      710517            1125
# 1426  23044          Val Portlock      924989            3143
# 1522  23960  Kristopher Lagerberg      658777            1392
# 1686  25615         Olevia Morena      388477             812
# 1812  26758      Angelena Billman      942074             629
# 1981  28360        Rashad Cascone      924517            3212
# 2131  29608       Willetta Lurvey      800568            1028
# ...

# %%
# หาหมายเลขที่อยู่สูงสุดบนถนน Northwestern Dr
last_house_number = person1_df['address_number'].max()

# กรองหาคนที่อาศัยอยู่ที่บ้านหลังสุดท้าย
person1_witness = person1_df[person1_df['address_number'] == last_house_number]

# แสดงข้อมูลพยานคนแรก
person1_witness
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#            ssn
# 499  111564949

# %% [markdown]
# ## หาพยานคนที่ 2

# %%
person2_df = person_df[person_df['address_street_name'] == 'Franklin Ave']
person2_witness = person2_df[person2_df['name'].str.contains('Annabel')]
person2_witness
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %% [markdown]
# ## ดูการให้ปากกาคำของพยาน

# %%
path_to_intereview = '/content/drive/MyDrive/Python&DataViz2025/Midterm/interview.csv'

# %%
interreview_df = pd.read_csv(path_to_intereview)
interreview_df.head(3)
# Out:
#    person_id                                     transcript
# 0      28508            ‘I deny it!’ said the March Hare.\n
# 1      63713                                             \n
# 2      86208  way, and the whole party swam to the shore.\n

# %%
interreview1 = interreview_df[interreview_df['person_id'] == 14887]

if not interreview1.empty:
    for index, row in interreview1.iterrows():
        print(f"--- Row Index: {index} ---")
        for column, value in row.items():
            print(f"{column}: {value}")
else:
    print("DataFrame 'interreview1' is empty.")
# Out:
# --- Row Index: 4988 ---
# person_id: 14887
# transcript: I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".

# %% [markdown]
# --- Row Index: 4988 ---
#
# person_id: 14887
#
# transcript:ฉันได้ยินเสียงปืนแล้วเห็นชายคนหนึ่งวิ่งออกมา เขามีกระเป๋าของ "Get Fit Now Gym" หมายเลขสมาชิกบนกระเป๋าขึ้นต้นด้วย "48Z" เฉพาะสมาชิกระดับ Gold เท่านั้นที่มีกระเป๋าแบบนี้ ชายคนนั้นขึ้นรถยนต์ที่มีป้ายทะเบียนมีส่วนประกอบของ "H42W" อยู่ด้วย

# %%
interreview2 = interreview_df[interreview_df['person_id'] == 16371]

if not interreview2.empty:
    for index, row in interreview2.iterrows():
        print(f"--- Row Index: {index} ---")
        for column, value in row.items():
            print(f"{column}: {value}")
else:
    print("DataFrame 'interreview2' is empty.")
# Out:
# --- Row Index: 4989 ---
# person_id: 16371
# transcript: I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %% [markdown]
# --- Row Index: 4989 ---
#
# person_id: 16371
#
# transcript:ฉันเห็นเหตุฆาตกรรมเกิดขึ้น และฉันจำฆาตกรได้ว่าเคยเห็นเขาที่ฟิตเนสตอนที่ฉันไปออกกำลังกายเมื่อสัปดาห์ที่แล้ว วันที่ 9 มกราคม

# %% [markdown]
# # สรุปข้อมูลที่ใช้หาฆาตกร
#
# - มีกระเป๋าของ "Get Fit Now Gym"
# - หมายเลขสมาชิกบนกระเป๋าขึ้นต้นด้วย "48Z"
# - เฉพาะสมาชิกระดับ Gold เท่านั้นที่มีกระเป๋าแบบนี้
# - ชายคนนั้นขึ้นรถยนต์ที่มีป้ายทะเบียนมีส่วนประกอบของ "H42W"
# - วันที่ 9 มกราคม เขาออกไปฟิตเนส

# %% [markdown]
# ## ตรวจสอบฟิตเนส

# %%
path_to_getfitnow_member = '/content/drive/MyDrive/Python&DataViz2025/Midterm/get_fit_now_member.csv'

# %%
getfitnow_member = pd.read_csv(path_to_getfitnow_member)
getfitnow_member.head(3)
# Out:
#       id  person_id                name  membership_start_date  \
# 0  NL318      65076     Everette Koepke               20170926
# 1  AOE21      39426        Noe Locascio               20171005
# 2  2PN28      63823  Jeromy Heitschmidt               20180215
#
#   membership_status
# 0              gold
# 1           regular
# 2            silver

# %%
getfitnow_member_gold = getfitnow_member[getfitnow_member['membership_status'] == 'gold']
getfitnow_member_gold = getfitnow_member_gold[getfitnow_member_gold['id'].str.contains('48Z')]
getfitnow_member_gold
# Out:
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# ### ตรวจสอบว่าไปฟิตเนสวันที่ 9 มกราไหม

# %%
path_to_getfitnow_checkin = '/content/drive/MyDrive/Python&DataViz2025/Midterm/get_fit_now_check_in.csv'

# %%
getfitnow_checkin = pd.read_csv(path_to_getfitnow_checkin)
getfitnow_checkin
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 0            NL318       20180212            329             365
# 1            NL318       20170811            469             920
# 2            NL318       20180429            506             554
# 3            NL318       20180128            124             759
# 4            NL318       20171027            418            1019
# ...            ...            ...            ...             ...
# 2698         4KB72       20170422           1016            1114
# 2699         4KB72       20170630            408             885
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700
#
# [2703 rows x 4 columns]

# %%
filtered_checkins = getfitnow_checkin[
    getfitnow_checkin['membership_id'].isin(['48Z7A', '48Z55']) &
    (getfitnow_checkin['check_in_date'] == 20180109)
]
filtered_checkins
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700

# %% [markdown]
# ผู้ต้องสงสัย
# 1. Member id :48Z7A
#
#    person id : 28819
#
#    Name : Joe Germuska
#
# 2. Member id : 48Z55
#
#    person id : 67318
#
#    Name : Jeremy Bowers

# %%
murderer_car = drivers_license[drivers_license['plate_number'].str.contains('H42W')]
murderer_car
# Out:
#           id  age  height eye_color hair_color  gender plate_number  \
# 915   183779   21      65      blue     blonde  female       H42W0X
# 3529  423327   30      70     brown      brown    male       0H42W2
# 6240  664760   21      71     black      black    male       4H42WR
#
#        car_make car_model
# 915      Toyota     Prius
# 3529  Chevrolet  Spark LS
# 6240     Nissan    Altima

# %%
murderer = person_df[person_df['license_id'].isin([183779, 423327])]
murderer
# Out:
#          id            name  license_id  address_number  \
# 6327  67318   Jeremy Bowers      423327             530
# 7578  78193  Maxine Whitely      183779             110
#
#         address_street_name        ssn
# 6327  Washington Pl, Apt 3A  871539279
# 7578                Fisk Rd  137882671

# %% [markdown]
# # สรุปฆาตกร
#
# จากข้อมูล
# - มีกระเป๋าของ "Get Fit Now Gym"
# - หมายเลขสมาชิกบนกระเป๋าขึ้นต้นด้วย "48Z"
# - เฉพาะสมาชิกระดับ Gold เท่านั้นที่มีกระเป๋าแบบนี้
# - ชายคนนั้นขึ้นรถยนต์ที่มีป้ายทะเบียนมีส่วนประกอบของ "H42W"
# - วันที่ 9 มกราคม เขาออกไปฟิตเนส
#
# สามารถสรุปตัวคนร้ายได้ คือ
#
# **Name : Jeremy Bowers**
#
# person id : 67318

# %% [markdown]
# ## ตรวจสอบคำให้การคนร้าย

# %%
interview_Jeremy = interreview_df[interreview_df['person_id'] == 67318]

if not interview_Jeremy.empty:
    for index, row in interview_Jeremy.iterrows():
        print(f"--- Row Index: {index} ---")
        for column, value in row.items():
            print(f"{column}: {value}")
else:
    print("DataFrame 'interview_Jeremy' is empty.")
# Out:
# --- Row Index: 4990 ---
# person_id: 67318
# transcript: I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.

# %% [markdown]
# ### Jeremy ให้การ
# person_id: 67318
#
# transcript : ฉันถูกว่าจ้างโดยผู้หญิงคนหนึ่งที่มีเงินมาก
# ฉันไม่รู้จักชื่อของเธอ แต่ฉันรู้ว่าเธอสูงประมาณ 5 ฟุต 5 นิ้ว (65 นิ้ว) หรือ 5 ฟุต 7 นิ้ว (67 นิ้ว)
# เธอมีผมสีแดง และขับรถเทสล่า รุ่น Model S
# ฉันรู้ว่าเธอเคยไปงาน SQL Symphony Concert 3 ครั้งในเดือนธันวาคม ปี 2017

# %% [markdown]
# # หาคนบงการ
# - ผู้หญิงมีเงินมาก
# - เธอสูงประมาณ 5 ฟุต 5 นิ้ว (65 นิ้ว) หรือ 5 ฟุต 7 นิ้ว (67 นิ้ว)
# - มีผมสีแดง
# - ขับรถเทสล่า รุ่น Model S
# - เธอเคยไปงาน SQL Symphony Concert 3 ครั้งในเดือนธันวาคม ปี 2017

# %% [markdown]
# ## ตรวจสอบรถ

# %%
path_to_drivers_license = '/content/drive/MyDrive/Python&DataViz2025/Midterm/drivers_license.csv'

# %%
drivers_license = pd.read_csv(path_to_drivers_license)

# %%
mastermind_car = drivers_license[
    (drivers_license['hair_color'] == 'red') &
    (drivers_license['gender'] == 'female') &
    (drivers_license['car_make'] == 'Tesla') &
    (drivers_license['car_model'] == 'Model S')
]
mastermind_car
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model
# 1105   Model S
# 2054   Model S
# 9078   Model S

# %% [markdown]
# ## หาไอดี เทียบ เลขใบขับขี่

# %%
mastermind1 = person_df[person_df['license_id'] == 202298]
mastermind1
# Out:
#          id              name  license_id  address_number address_street_name  \
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn
# 9985  987756388

# %%
mastermind2 = person_df[person_df['license_id'] == 291182]
mastermind2
# Out:
#          id           name  license_id  address_number address_street_name  \
# 8977  90700  Regina George      291182             332           Maple Ave
#
#             ssn
# 8977  337169072

# %%
mastermind3 = person_df[person_df['license_id'] == 	918773]
mastermind3
# Out:
#          id      name  license_id  address_number address_street_name  \
# 7664  78881  Red Korb      918773             107         Camerata Dr
#
#             ssn
# 7664  961388910

# %% [markdown]
# ##เทียบ ssn กับรายได้

# %%
path_to_income = '/content/drive/MyDrive/Python&DataViz2025/Midterm/income.csv'

# %%
income_df = pd.read_csv(path_to_income)

# %%
#คนที่1
mastermind1_income = income_df[income_df['ssn'] == 987756388]
mastermind1_income
# Out:
#             ssn  annual_income
# 7422  987756388         310000

# %%
#คนที่2
mastermind2_income = income_df[income_df['ssn'] == 3337169072]
mastermind2_income
# Out:
# Empty DataFrame
# Columns: [ssn, annual_income]
# Index: []

# %%
#คนที่3
mastermind3_income = income_df[income_df['ssn'] == 961388910]
mastermind3_income
# Out:
#             ssn  annual_income
# 7207  961388910         278000

# %% [markdown]
# ผู้ต้องสงสัยคนบงการ เหลือแค่
#
# **Mastermind1**
#
# Name : Miranda Priestly
#
# ssn : 987756388
#
# **Mastermind3**
#
# Name : Red Korb
#
# ssn : 961388910

# %% [markdown]
# ## ตรวจสอบ Event

# %%
path_to_event = '/content/drive/MyDrive/Python&DataViz2025/Midterm/facebook_event_checkin.csv'

# %%
event_df = pd.read_csv(path_to_event)
event_df
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
#คนที่1
mastermind1_event = event_df[event_df['person_id'] == 99716]
mastermind1_event
# Out:
#        person_id  event_id            event_name      date
# 20006      99716      1143  SQL Symphony Concert  20171206
# 20007      99716      1143  SQL Symphony Concert  20171212
# 20008      99716      1143  SQL Symphony Concert  20171229

# %%
#คนที่3
mastermind3_event = event_df[event_df['person_id'] == 78881]
mastermind3_event
# Out:
# Empty DataFrame
# Columns: [person_id, event_id, event_name, date]
# Index: []

# %% [markdown]
# #สรุปคนบงการ
#
# จากข้อมูลหลักฐาน ได้แก่
# - ผู้หญิงมีเงินมาก
# - เธอสูงประมาณ 5 ฟุต 5 นิ้ว (65 นิ้ว) หรือ 5 ฟุต 7 นิ้ว (67 นิ้ว)
# - มีผมสีแดง
# - ขับรถเทสล่า รุ่น Model S
# - เธอเคยไปงาน SQL Symphony Concert 3 ครั้งในเดือนธันวาคม ปี 2017
#
# สามารถสรุปผู้บงการการฆาตกรรมครั้งนี้ คือ
#
# Name : Miranda Priestly
#
# Id : 99716

# %% [markdown]
# # ตอบคำถาม
#  ให้สืบหาฆาตรกร (10 คะแนน) และ ผู้บงการ (5 คะแนน) ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง Pandas City โดยเริ่มจากการตรวจสอบ ข้อมูลคดีในไฟล์ crime_scene_report.csv

# %% [markdown]
# ▶ **Murderer** 🔪🔪🔪
#
# Name : Jeremy Bowers
#
# person id : 67318
#
# ▶ **Mindmaster** 🧠🧠🧠
#
# Name : Miranda Priestly
#
# Id : 99716
